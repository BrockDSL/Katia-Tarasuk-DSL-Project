# %%
# import pandas as the library we will be preparing the data with
import pandas as pd
import numpy as np

# %%
# read the file into a variable
df = pd.read_csv("Daily 2019.csv")

# view the basics of the dataframe: the number of rows and columns and their names, as well as how many times there is
# non existant data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 31 columns):
# Longitude (x)                365 non-null float64
# Latitude (y)                 365 non-null float64
# Station Name                 365 non-null object
# Climate ID                   365 non-null int64
# Date/Time                    365 non-null object
# Year                         365 non-null int64
# Month                        365 non-null int64
# Day                          365 non-null int64
# Data Quality                 0 non-null float64
# Max Temp (°C)                306 non-null float64
# Max Temp Flag                4 non-null object
# Min Temp (°C)                306 non-null float64
# Min Temp Flag                4 non-null object
# Mean Temp (°C)               306 non-null float64
# Mean Temp Flag               4 non-null object
# Heat Deg Days (°C)           306 non-null float64
# Heat Deg Days Flag           4 non-null object
# Cool Deg Days (°C)           306 non-null float64
# Cool Deg Days Flag           4 non-null object
# Total Rain (mm)              0 non-null float64
# Total Rain Flag              0 non-null float64
# Total Snow (cm)              0 non-null float64
# Total Snow Flag              0 non-null float64
# Total Precip (mm)            0 non-null float64
# Total Precip Flag            310 non-null object
# Snow on Grnd (cm)            0 non-null float64
# Snow on Grnd Flag            0 non-null float64
# Dir of Max Gust (10s deg)    167 non-null float64
# Dir of Max Gust Flag         0 non-null float64
# Spd of Max Gust (km/h)       167 non-null float64
# Spd of Max Gust Flag         0 non-null float64
# dtypes: float64(19), int64(4), object(8)
# memory usage: 88.5+ KB

# %%
#view the topmost rows using head. Head by default displays the top 5
df.head()
# Out:
#    Longitude (x)  Latitude (y)     Station Name  Climate ID   Date/Time  Year  \
# 0         -79.17         43.19  ST CATHARINES A     6137304  2019-01-01  2019
# 1         -79.17         43.19  ST CATHARINES A     6137304  2019-01-02  2019
# 2         -79.17         43.19  ST CATHARINES A     6137304  2019-01-03  2019
# 3         -79.17         43.19  ST CATHARINES A     6137304  2019-01-04  2019
# 4         -79.17         43.19  ST CATHARINES A     6137304  2019-01-05  2019
#
#    Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0      1    1           NaN           12.0  ...             NaN
# 1      1    2           NaN            2.9  ...             NaN
# 2      1    3           NaN            3.0  ...             NaN
# 3      1    4           NaN            8.0  ...             NaN
# 4      1    5           NaN            3.5  ...             NaN
#
#    Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0              NaN               NaN                  M               NaN
# 1              NaN               NaN                  M               NaN
# 2              NaN               NaN                  M               NaN
# 3              NaN               NaN                  M               NaN
# 4              NaN               NaN                  M               NaN
#
#    Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                NaN                      26.0                   NaN
# 1                NaN                       NaN                   NaN
# 2                NaN                      27.0                   NaN
# 3                NaN                      21.0                   NaN
# 4                NaN                       NaN                   NaN
#
#   Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                   62.0                   NaN
# 1                    NaN                   NaN
# 2                   45.0                   NaN
# 3                   55.0                   NaN
# 4                    NaN                   NaN
#
# [5 rows x 31 columns]

# %%
#view the bottom row using tail. Tail by default displays the bottom 5
df.tail(3)
# Out:
#      Longitude (x)  Latitude (y)     Station Name  Climate ID   Date/Time  \
# 362         -79.17         43.19  ST CATHARINES A     6137304  2019-12-29
# 363         -79.17         43.19  ST CATHARINES A     6137304  2019-12-30
# 364         -79.17         43.19  ST CATHARINES A     6137304  2019-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 362  2019     12   29           NaN            NaN  ...             NaN
# 363  2019     12   30           NaN            NaN  ...             NaN
# 364  2019     12   31           NaN            NaN  ...             NaN
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 362              NaN               NaN                NaN               NaN
# 363              NaN               NaN                NaN               NaN
# 364              NaN               NaN                NaN               NaN
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 362                NaN                       NaN                   NaN
# 363                NaN                       NaN                   NaN
# 364                NaN                       NaN                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 362                    NaN                   NaN
# 363                    NaN                   NaN
# 364                    NaN                   NaN
#
# [3 rows x 31 columns]

# %%
#to view the basic statistic of a given column of numbers (integers or floats), use df['row_name'].describe
df['Max Temp (°C)'].describe()
# Out:
# count    306.000000
# mean      15.453595
# std       11.156617
# min      -13.500000
# 25%        6.825000
# 50%       17.400000
# 75%       24.800000
# max       33.600000
# Name: Max Temp (°C), dtype: float64

# %%
# we don't want all of these columns in the dataframe, as we are only going to be using specific columns' data, so we're going
# to pick out the columns that we want to use, and reassign the data that we want to a new variable called df1
df1 = df[['Year','Month','Day','Max Temp (°C)','Min Temp (°C)']]

# if we are using Jupyter and want to view the dataframe quickly, all that we need to do is type the variable and run the cell
df1
# Out:
#      Year  Month  Day  Max Temp (°C)  Min Temp (°C)
# 0    2019      1    1           12.0           -4.3
# 1    2019      1    2            2.9           -5.0
# 2    2019      1    3            3.0            0.1
# 3    2019      1    4            8.0           -3.0
# 4    2019      1    5            3.5           -4.1
# 5    2019      1    6            4.3           -5.0
# 6    2019      1    7            6.7           -5.6
# 7    2019      1    8            9.3            2.7
# 8    2019      1    9            3.1           -3.3
# 9    2019      1   10           -3.3           -7.3
# 10   2019      1   11           -6.2          -10.0
# 11   2019      1   12           -3.5           -6.5
# 12   2019      1   13           -4.2           -8.8
# 13   2019      1   14           -1.4          -11.3
# 14   2019      1   15            0.1           -3.8
# 15   2019      1   16            1.2          -10.7
# 16   2019      1   17           -3.9          -12.2
# 17   2019      1   18            0.7           -4.5
# 18   2019      1   19           -3.6           -9.8
# 19   2019      1   20           -9.8          -17.8
# 20   2019      1   21          -10.2          -17.9
# 21   2019      1   22            1.5          -17.9
# 22   2019      1   23            8.5            0.4
# 23   2019      1   24            4.7           -3.0
# 24   2019      1   25           -2.3          -10.2
# 25   2019      1   26           -3.9          -11.9
# 26   2019      1   27           -0.4          -12.0
# 27   2019      1   28           -5.7          -15.5
# 28   2019      1   29            1.0          -13.9
# 29   2019      1   30          -13.5          -20.1
# ..    ...    ...  ...            ...            ...
# 335  2019     12    2            NaN            NaN
# 336  2019     12    3            NaN            NaN
# 337  2019     12    4            NaN            NaN
# 338  2019     12    5            NaN            NaN
# 339  2019     12    6            NaN            NaN
# 340  2019     12    7            NaN            NaN
# 341  2019     12    8            NaN            NaN
# 342  2019     12    9            NaN            NaN
# 343  2019     12   10            NaN            NaN
# 344  2019     12   11            NaN            NaN
# 345  2019     12   12            NaN            NaN
# 346  2019     12   13            NaN            NaN
# 347  2019     12   14            NaN            NaN
# 348  2019     12   15            NaN            NaN
# 349  2019     12   16            NaN            NaN
# 350  2019     12   17            NaN            NaN
# 351  2019     12   18            NaN            NaN
# 352  2019     12   19            NaN            NaN
# 353  2019     12   20            NaN            NaN
# 354  2019     12   21            NaN            NaN
# 355  2019     12   22            NaN            NaN
# 356  2019     12   23            NaN            NaN
# 357  2019     12   24            NaN            NaN
# 358  2019     12   25            NaN            NaN
# 359  2019     12   26            NaN            NaN
# 360  2019     12   27            NaN            NaN
# 361  2019     12   28            NaN            NaN
# 362  2019     12   29            NaN            NaN
# 363  2019     12   30            NaN            NaN
# 364  2019     12   31            NaN            NaN
#
# [365 rows x 5 columns]

# %%
# Now there is a lot of NaN's (or non-existant data) in the columns that we are going to be using, especially towards the end of
# the dataframe as I had downloaded this particular set of data on November 7th, 2019. That being said, we cannot guarantee that
# there are rows randomly sprinkled throughout the dataframe that also have NaN in place of actual data. So we are going to
# filter out the rows that have 3 or more NaN's. df.dropna(thresh=n) will give us a dataframe that has at least n definite
# values, but let's say that we want to filter out rows with at least n NaN's instead of filtering the definite values, so we 
# use df.dropna(thresh=df.shape[1]-n)

# in this example we want to filter the rows that have 2 NaN's in the Min and Max Temp Columns, so we can use:
df2 = df1.dropna(subset=['Max Temp (°C)','Min Temp (°C)'], thresh=2)
df2
# Out:
#      Year  Month  Day  Max Temp (°C)  Min Temp (°C)
# 0    2019      1    1           12.0           -4.3
# 1    2019      1    2            2.9           -5.0
# 2    2019      1    3            3.0            0.1
# 3    2019      1    4            8.0           -3.0
# 4    2019      1    5            3.5           -4.1
# 5    2019      1    6            4.3           -5.0
# 6    2019      1    7            6.7           -5.6
# 7    2019      1    8            9.3            2.7
# 8    2019      1    9            3.1           -3.3
# 9    2019      1   10           -3.3           -7.3
# 10   2019      1   11           -6.2          -10.0
# 11   2019      1   12           -3.5           -6.5
# 12   2019      1   13           -4.2           -8.8
# 13   2019      1   14           -1.4          -11.3
# 14   2019      1   15            0.1           -3.8
# 15   2019      1   16            1.2          -10.7
# 16   2019      1   17           -3.9          -12.2
# 17   2019      1   18            0.7           -4.5
# 18   2019      1   19           -3.6           -9.8
# 19   2019      1   20           -9.8          -17.8
# 20   2019      1   21          -10.2          -17.9
# 21   2019      1   22            1.5          -17.9
# 22   2019      1   23            8.5            0.4
# 23   2019      1   24            4.7           -3.0
# 24   2019      1   25           -2.3          -10.2
# 25   2019      1   26           -3.9          -11.9
# 26   2019      1   27           -0.4          -12.0
# 27   2019      1   28           -5.7          -15.5
# 28   2019      1   29            1.0          -13.9
# 29   2019      1   30          -13.5          -20.1
# ..    ...    ...  ...            ...            ...
# 280  2019     10    8           17.8            4.5
# 281  2019     10    9           18.4            4.3
# 282  2019     10   10           17.9            3.9
# 283  2019     10   11           22.3            5.5
# 284  2019     10   12           15.9            3.1
# 285  2019     10   13           18.7            4.1
# 286  2019     10   14           12.5            2.0
# 287  2019     10   15           15.8            1.4
# 288  2019     10   16           16.1            6.7
# 289  2019     10   17            9.6            8.1
# 290  2019     10   18           11.5            0.6
# 291  2019     10   19           13.9           -0.2
# 292  2019     10   20           17.4            1.9
# 293  2019     10   21           20.7            3.6
# 294  2019     10   22           16.8            9.1
# 295  2019     10   23           14.7            7.2
# 296  2019     10   24           16.9            5.5
# 297  2019     10   25           11.3            5.1
# 298  2019     10   26           13.0            0.3
# 299  2019     10   27           17.0            9.1
# 300  2019     10   28           17.4            4.1
# 301  2019     10   29           19.1            3.7
# 302  2019     10   30           12.2            9.3
# 303  2019     10   31           14.1            4.6
# 304  2019     11    1            4.8           -0.4
# 305  2019     11    2            8.1            0.9
# 306  2019     11    3            7.4           -1.0
# 307  2019     11    4           12.8            2.0
# 308  2019     11    5           10.9            1.8
# 309  2019     11    6            6.2           -1.8
#
# [306 rows x 5 columns]

# %%
# but let's say that we want to filter out everything from November 7th on, and ignore if there are any random other rows with 
# NaN's. So what we can do is:
df2b = df1[(df.Month < 11)|((df.Month == 11)&(df.Day < 7))]
df2b
# Basically this filters the data into a new dataframe, df2b, where the number of the month is either less than 11 (November), 
# or the month is 11 and the date is less than the 7th
# Out:
#      Year  Month  Day  Max Temp (°C)  Min Temp (°C)
# 0    2019      1    1           12.0           -4.3
# 1    2019      1    2            2.9           -5.0
# 2    2019      1    3            3.0            0.1
# 3    2019      1    4            8.0           -3.0
# 4    2019      1    5            3.5           -4.1
# 5    2019      1    6            4.3           -5.0
# 6    2019      1    7            6.7           -5.6
# 7    2019      1    8            9.3            2.7
# 8    2019      1    9            3.1           -3.3
# 9    2019      1   10           -3.3           -7.3
# 10   2019      1   11           -6.2          -10.0
# 11   2019      1   12           -3.5           -6.5
# 12   2019      1   13           -4.2           -8.8
# 13   2019      1   14           -1.4          -11.3
# 14   2019      1   15            0.1           -3.8
# 15   2019      1   16            1.2          -10.7
# 16   2019      1   17           -3.9          -12.2
# 17   2019      1   18            0.7           -4.5
# 18   2019      1   19           -3.6           -9.8
# 19   2019      1   20           -9.8          -17.8
# 20   2019      1   21          -10.2          -17.9
# 21   2019      1   22            1.5          -17.9
# 22   2019      1   23            8.5            0.4
# 23   2019      1   24            4.7           -3.0
# 24   2019      1   25           -2.3          -10.2
# 25   2019      1   26           -3.9          -11.9
# 26   2019      1   27           -0.4          -12.0
# 27   2019      1   28           -5.7          -15.5
# 28   2019      1   29            1.0          -13.9
# 29   2019      1   30          -13.5          -20.1
# ..    ...    ...  ...            ...            ...
# 280  2019     10    8           17.8            4.5
# 281  2019     10    9           18.4            4.3
# 282  2019     10   10           17.9            3.9
# 283  2019     10   11           22.3            5.5
# 284  2019     10   12           15.9            3.1
# 285  2019     10   13           18.7            4.1
# 286  2019     10   14           12.5            2.0
# 287  2019     10   15           15.8            1.4
# 288  2019     10   16           16.1            6.7
# 289  2019     10   17            9.6            8.1
# 290  2019     10   18           11.5            0.6
# 291  2019     10   19           13.9           -0.2
# 292  2019     10   20           17.4            1.9
# 293  2019     10   21           20.7            3.6
# 294  2019     10   22           16.8            9.1
# 295  2019     10   23           14.7            7.2
# 296  2019     10   24           16.9            5.5
# 297  2019     10   25           11.3            5.1
# 298  2019     10   26           13.0            0.3
# 299  2019     10   27           17.0            9.1
# 300  2019     10   28           17.4            4.1
# 301  2019     10   29           19.1            3.7
# 302  2019     10   30           12.2            9.3
# 303  2019     10   31           14.1            4.6
# 304  2019     11    1            4.8           -0.4
# 305  2019     11    2            8.1            0.9
# 306  2019     11    3            7.4           -1.0
# 307  2019     11    4           12.8            2.0
# 308  2019     11    5           10.9            1.8
# 309  2019     11    6            6.2           -1.8
#
# [310 rows x 5 columns]
